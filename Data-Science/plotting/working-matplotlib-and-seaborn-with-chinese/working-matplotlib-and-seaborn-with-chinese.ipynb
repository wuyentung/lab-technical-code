# %%
from random import randint
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame({
    '年份': ['2013', '2014', '2015', '2016', '2017', '2019'],
    '價格': [randint(100, 10000) for _ in range(6)]
})
df
# Out:
#      年份    價格
# 0  2013  2478
# 1  2014  9836
# 2  2015  5886
# 3  2016  8206
# 4  2017  3538
# 5  2019  6002

# %% [markdown]
# ## Default settings

# %% [markdown]
# ### matplotlib

# %%
plt.plot(
    df['年份'],
    df['價格']
)
plt.xlabel('年份')
plt.ylabel('價格')
plt.savefig('./does-not-show-chinese.png')
# Out:
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# ### Seaborn

# %%
sns.lineplot(x="年份", y="價格", data=df)
# Out:
# <AxesSubplot:xlabel='年份', ylabel='價格'>
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 20729 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/textpath.py:74: RuntimeWarning: Glyph 26684 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Change settings

# %%
# find the default font of matplotlib
from matplotlib.font_manager import findfont, FontProperties  


findfont(FontProperties(family=FontProperties().get_family()))
# Out:
# '/Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'

# %%
# find the path of matplotlibrc
import matplotlib


matplotlib.matplotlib_fname()
# Out:
# '/Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
! open /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
! open /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf

# %% [markdown]
# ## Revmove the cache of matplotlib

# %%
! rm -rf ~/.matplotlib

# %% [markdown]
# ## Copy your font file into matplotlib

# %% [markdown]
# Copy your `.ttf` to `/font/ttf/`
#
# Restart your Jupyter Notebook

# %% [markdown]
# ---

# %% [markdown]
# ## After change the settings

# %%
# find the default font of matplotlib
from matplotlib.font_manager import findfont, FontProperties  


findfont(FontProperties(family=FontProperties().get_family()))
# Out:
# '/Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'

# %%
# check the default font
import matplotlib.pyplot as plt


plt.rcParams['font.sans-serif']
# Out:
# ['SimHei',
#  'DejaVu Sans',
#  'Bitstream Vera Sans',
#  'Computer Modern Sans Serif',
#  'Lucida Grande',
#  'Verdana',
#  'Geneva',
#  'Lucid',
#  'Arial',
#  'Helvetica',
#  'Avant Garde',
#  'sans-serif']

# %%
plt.plot(
    df['年份'],
    df['價格']
)
plt.xlabel('年份')
plt.ylabel('價格')
plt.savefig('./show-chinese.png')
# Out:
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/tungwu/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
ax = sns.lineplot(x="年份", y="價格", data=df)

# %%
sns.set(style='darkgrid', font='SimHei', rc={'figure.figsize':(12, 8)}, font_scale=1.3)
ax = sns.lineplot(x="年份", y="價格", data=df)
ax.figure.savefig('./seaborn-plot.png')
